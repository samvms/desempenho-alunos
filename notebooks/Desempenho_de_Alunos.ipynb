# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Analisando os dados

# %%
df = pd.read_csv('/content/StudentPerformanceFactors.csv')
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
for col in df.columns:
  print(f'{col}: {df[col].unique()}')
  print('-'*20)
# Out:
# Hours_Studied: [23 19 24 29 25 17 21  9 10 14 22 15 12 20 11 13 16 18 31  8 26 28  4 35
#  27 33 36 43 34  1 30  7 32  6 38  5  3  2 39 37 44]
# --------------------
# Attendance: [ 84  64  98  89  92  88  78  94  80  97  83  82  68  60  70  75  99  74
#   65  62  91  90  66  69  72  63  61  86  77  71  67  87  73  96 100  81
#   95  79  85  76  93]
# --------------------
# Parental_Involvement: ['Low' 'Medium' 'High']
# --------------------
# Access_to_Resources: ['High' 'Medium' 'Low']
# --------------------
# Extracurricular_Activities: ['No' 'Yes']
# --------------------
# Sleep_Hours: [ 7  8  6 10  9  5  4]
# --------------------
# Previous_Scores: [ 73  59  91  98  65  89  68  50  80  71  88  87  97  72  74  70  82  58
#   99  84 100  75  54  90  94  51  57  66  96  93  56  52  63  79  81  69
#   95  60  92  77  62  85  78  64  76  55  86  61  53  83  67]
# --------------------
# Motivation_Level: ['Low' 'Medium' 'High']
# --------------------
# Internet_Access: ['Yes' 'No']
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %% [markdown]
# # Traduzindo as colunas

# %%
colunas_traduzidas = {
    "Attendance": "Presença",
    "Parental_Involvement": "Envolvimento_Paternal",
    "Access_to_Resources": "Acesso_a_Recursos",
    "Extracurricular_Activities": "Atividades_Extracurriculares",
    "Sleep_Hours": "Horas_de_Sono",
    "Previous_Scores": "Pontuações_Anteriores",
    "Motivation_Level": "Nível_de_Motivação",
    "Internet_Access": "Acesso_à_Internet",
    "Tutoring_Sessions": "Sessões_de_Tutoria",
    "Family_Income": "Renda_Familiar",
    "Teacher_Quality": "Qualidade_do_Professor",
    "School_Type": "Tipo_de_Escola",
    "Peer_Influence": "Influência_dos_Pares",
    "Physical_Activity": "Atividade_Física",
    "Learning_Disabilities": "Deficiências_de_Aprendizagem",
    "Parental_Education_Level": "Nível_de_Educação_Paternal",
    "Distance_from_Home": "Distância_de_Casa",
    "Gender": "Gênero",
    "Hours_Studied": "Horas_Estudadas",
    "Exam_Score": "Pontuação_da_Prova"
}

valores_traduzidos = {
    "Low": "Baixo",
    "Medium": "Médio",
    "High": "Alto",
    "No": "Não",
    "Yes": "Sim",
    "Public": "Pública",
    "Private": "Particular",
    "Positive": "Positiva",
    "Negative": "Negativa",
    "Neutral": "Neutra",
    "High School": "Ensino Médio",
    "College": "Faculdade",
    "Postgraduate": "Pós-graduação",
    "Near": "Perto",
    "Moderate": "Moderado",
    "Far": "Longe",
    "Male": "Masculino",
    "Female": "Feminino"
}

# %%
df.rename(columns=colunas_traduzidas, inplace=True)
df.replace(valores_traduzidos, inplace=True)

# %%
df
# Out:
#       Horas_Estudadas  Presença Envolvimento_Paternal Acesso_a_Recursos  \
# 0                  23        84                 Baixo              Alto
# 1                  19        64                 Baixo             Médio
# 2                  24        98                 Médio             Médio
# 3                  29        89                 Baixo             Médio
# 4                  19        92                 Médio             Médio
# ...               ...       ...                   ...               ...
# 6602               25        69                  Alto             Médio
# 6603               23        76                  Alto             Médio
# 6604               20        90                 Médio             Baixo
# 6605               10        86                  Alto              Alto
# 6606               15        67                 Médio             Baixo
#
#      Atividades_Extracurriculares  Horas_de_Sono  Pontuações_Anteriores  \
# ...

# %%
for col in df.columns:
  print(f'{col}: {df[col].unique()}')
  print('-'*20)
# Out:
# Horas_Estudadas: [23 19 24 29 25 17 21  9 10 14 22 15 12 20 11 13 16 18 31  8 26 28  4 35
#  27 33 36 43 34  1 30  7 32  6 38  5  3  2 39 37 44]
# --------------------
# Presença: [ 84  64  98  89  92  88  78  94  80  97  83  82  68  60  70  75  99  74
#   65  62  91  90  66  69  72  63  61  86  77  71  67  87  73  96 100  81
#   95  79  85  76  93]
# --------------------
# Envolvimento_Paternal: ['Baixo' 'Médio' 'Alto']
# --------------------
# Acesso_a_Recursos: ['Alto' 'Médio' 'Baixo']
# --------------------
# Atividades_Extracurriculares: ['Não' 'Sim']
# --------------------
# Horas_de_Sono: [ 7  8  6 10  9  5  4]
# --------------------
# Pontuações_Anteriores: [ 73  59  91  98  65  89  68  50  80  71  88  87  97  72  74  70  82  58
#   99  84 100  75  54  90  94  51  57  66  96  93  56  52  63  79  81  69
#   95  60  92  77  62  85  78  64  76  55  86  61  53  83  67]
# --------------------
# Nível_de_Motivação: ['Baixo' 'Médio' 'Alto']
# --------------------
# ...

# %%
df.isnull().sum()
# Out:
# Horas_Estudadas                  0
# Presença                         0
# Envolvimento_Paternal            0
# Acesso_a_Recursos                0
# Atividades_Extracurriculares     0
# Horas_de_Sono                    0
# Pontuações_Anteriores            0
# Nível_de_Motivação               0
# Acesso_à_Internet                0
# Sessões_de_Tutoria               0
# Renda_Familiar                   0
# Qualidade_do_Professor          78
# Tipo_de_Escola                   0
# Influência_dos_Pares             0
# Atividade_Física                 0
# Deficiências_de_Aprendizagem     0
# Nível_de_Educação_Paternal      90
# Distância_de_Casa               67
# Gênero                           0
# Pontuação_da_Prova               0
# dtype: int64

# %%
df.loc[df['Nível_de_Educação_Paternal'].isnull()]
# Out:
#       Horas_Estudadas  Presença Envolvimento_Paternal Acesso_a_Recursos  \
# 240                15        87                 Baixo             Médio
# 408                21        65                  Alto              Alto
# 417                21        91                  Alto             Médio
# 451                26        94                  Alto             Médio
# 592                23        85                  Alto             Baixo
# ...               ...       ...                   ...               ...
# 6253               22        85                  Alto             Médio
# 6323               28        72                 Baixo              Alto
# 6411               19        92                  Alto             Médio
# 6423               21        70                 Médio              Alto
# 6502               23        64                 Médio             Médio
#
#      Atividades_Extracurriculares  Horas_de_Sono  Pontuações_Anteriores  \
# ...

# %% [markdown]
# # Removendo os dados nulos

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Horas_Estudadas                 0
# Presença                        0
# Envolvimento_Paternal           0
# Acesso_a_Recursos               0
# Atividades_Extracurriculares    0
# Horas_de_Sono                   0
# Pontuações_Anteriores           0
# Nível_de_Motivação              0
# Acesso_à_Internet               0
# Sessões_de_Tutoria              0
# Renda_Familiar                  0
# Qualidade_do_Professor          0
# Tipo_de_Escola                  0
# Influência_dos_Pares            0
# Atividade_Física                0
# Deficiências_de_Aprendizagem    0
# Nível_de_Educação_Paternal      0
# Distância_de_Casa               0
# Gênero                          0
# Pontuação_da_Prova              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# prompt: salva o df como excel

df.to_excel('desempenho_alunos.xlsx', index=False)
